# %% [markdown]
# <a href="https://colab.research.google.com/github/TEKIPAVAN/FMML_MODULE_Labs_and_Projects/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 06:14:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   235MB/s    in 0.3s
#
# 2024-04-03 06:14:03 (235 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39735  1703.03349v1  This paper deals with the problem of detecting...    cs
# 23908   1303.2465v1  For the purposes of foreground estimation, the...    cs
# 3800   1708.04764v1  Sparse Subspace Clustering (SSC) is a state-of...    cs
# 39039  1612.05460v2  We propose a general dual ascent framework for...    cs
# 21976   1211.3589v3  We study inference and learning based on a spa...  stat
# ...             ...                                                ...   ...
# 37138  1608.05288v2  Discrete optimization is a central problem in ...    cs
# 40513   1208.3145v1  We investigate two classes of transformations ...  stat
# 39332  1511.00099v1  Proliferation of touch-based devices has made ...    cs
# 22643  1703.05841v1  This work addresses various open questions in ...  stat
# 3589   1801.06432v1  Dictionary learning and component analysis mod...  stat
#
#                                                    title  year  \
# 39735  Fast and Robust Detection of Fallen People fro...  2017
# 23908  A Low-Complexity Algorithm for Static Backgrou...  2013
# 3800   Active Orthogonal Matching Pursuit for Sparse ...  2017
# 39039  A Dual Ascent Framework for Lagrangean Decompo...  2016
# 21976  A Truncated EM Approach for Spike-and-Slab Spa...  2012
# ...                                                  ...   ...
# 37138  Accelerating Exact and Approximate Inference f...  2016
# 40513  Metric distances derived from cosine similarit...  2012
# 39332  Sketch-based Image Retrieval from Millions of ...  2015
# 22643  Adaptivity to Noise Parameters in Nonparametri...  2017
# 3589                 Robust Kronecker Component Analysis  2018
#
#                                                 keywords
# 39735  [detecting, algorithm, segmentation, technique...
# 23908  [foreground, estimation, background, unavailab...
# 3800   [clustering, clustering, dimensional, dimensio...
# 39039  [framework, lagrangean, decomposition, combina...
# 21976  [inference, independent, distribution, applica...
# ...                                                  ...
# 37138  [optimization, artificial, intelligence, optim...
# 40513  [investigate, transformations, similarity, cor...
# 39332  [proliferation, retrieval, practical, detectio...
# 22643  [addresses, questions, nonparametric, classifi...
# 3589   [dictionary, component, fundamental, represent...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39735    [detecting, algorithm, segmentation, technique...
# 23908    [foreground, estimation, background, unavailab...
# 3800     [clustering, clustering, dimensional, dimensio...
# 39039    [framework, lagrangean, decomposition, combina...
# 21976    [inference, independent, distribution, applica...
#                                ...
# 9648     [compressed, reconstruct, representation, comb...
# 3482     [identification, challenging, multimedia, mult...
# 31598    [aggregating, convolutional, attracted, sustai...
# 24006    [combining, opportunities, possibilities, comb...
# 11242    [structured, prediction, consuming, approaches...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8731 words.
# Out of those 4566 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5283692d-e5ee-480d-af79-27db83012f0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5283692d-e5ee-480d-af79-27db83012f0e")) {                    Plotly.newPlot(                        "5283692d-e5ee-480d-af79-27db83012f0e",                        [{"x":["cluttered","relations","techniques","detecting","illumination","correctly","navigation","published","segmented","validated","environmental","detection","different","sequences","additionally","environments","classifiers","thoroughly","contribution","segmentation","algorithm","demonstrate","background","appropriate","conditional","estimates","practical","neighbourhood","indirectly","enforcing","maintained","continuity","sequential","representative","potentials","experiments","intervals","technique","structures","estimated","frequency","foreground","labelling","surveillance","filtering","computational","intensity","unavailable","considerably","complexity","estimation","framework","candidate","combination","conditions","circumstances","requirements","qualitatively","numerical","dimensional","algorithms","heuristic","clustering","adaptively","synthetic","improving","orthogonal","connectivity","efficiency","advantages","subspaces","separation","optimization","decomposition","particular","programming","outperforms","including","subgradient","performance","combinatorial","applicable","parameters","posteriors","comparison","application","distributions","inference","introduced","benchmarks","dimensions","independently","applications","increasing","corresponding","truncated","investigate","approaches","furthermore","saturates","independent","posterior","denoising","variational","independence","distribution","contributes","benchmark","properties","uncertainty","information","surprisingly","asymptotically","theoretic","shortcoming","simplicity","improvement","measurement","introduce","magnitude","measurements","modification","nevertheless","identification","collection","initiating","considered","incrementally","incorporated","probabilistic","simultaneously","avoidance","determined","extraction","resulting","configuration","likelihood","involving","membership","regularly","acquisition","motivated","exploration","construction","geostatistical","inclusion","principled","effective","functions","efficient","misleading","simulated","combining","considerations","portfolio","selection","definition","presented","regularized","objective","quantitative","preliminary","extensive","evaluation","consequence","classifier","evaluating","criterion","neuroimaging","optimizing","informative","interpretability","theoretical","automatic","circumvent","generation","narrative","difficult","important","interdependence","predicting","narratives","approximate","understanding","acquiring","knowledge","annotations","challenge","difficulties","collected","approximation","constrained","unconstrained","optimizers","approximated","questions","affirmative","challenging","polynomially","constrain"],"y":[9,92,355,74,38,40,30,35,23,38,17,355,781,96,67,78,105,13,90,225,857,570,73,81,107,80,144,5,5,6,9,6,92,39,12,587,21,227,136,62,59,23,16,29,78,277,34,4,27,185,226,570,56,133,143,8,47,18,83,176,579,51,149,25,152,128,17,29,170,91,20,34,348,74,259,138,267,260,1,907,44,47,250,2,143,249,100,209,121,100,43,50,435,91,127,10,157,477,160,1,124,31,48,57,21,203,13,232,210,80,704,24,14,52,6,21,144,31,307,55,54,33,16,97,70,3,150,16,30,165,105,5,36,128,151,30,68,44,21,3,31,54,56,71,0,9,24,244,218,418,7,57,98,13,1,153,40,160,32,166,79,42,158,253,18,139,60,36,1,50,41,21,171,211,5,140,9,142,386,2,82,4,98,188,13,333,67,149,25,72,124,72,23,3,21,68,0,268,3,13],"type":"bar"},{"x":["cluttered","relations","techniques","detecting","illumi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4566,), (4566, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>tableau</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>deontic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>logics</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>theorem</span> <span style=''>proving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3416458852867831);'>significant</span> <span style=''>fragment</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>language</span> <span style=''>made</span> <span style=''>up</span> <span style=''>of</span> <span style=''>(boolean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinations</span> <span style=''>of)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>statements</span> <span style=''>with</span> <span style=''>unnested</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>antecedents</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>possible</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.9370078740157481);'>semantics</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>logics</span> <span style=''>The</span> <span style=''>KEM</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>formalism</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>account</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.9370078740157481);'>semantics</span> <span style=''>of</span> <span style=''>normal</span> <span style=''>modal</span> <span style=''>logics</span> <span style=''>is</span> <span style=''>easily</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.9370078740157481);'>semantics</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>logics</span> <span style=''>by</span> <span style=''>simply</span> <span style=''>indexing</span> <span style=''>labels</span> <span style=''>with</span> <span style=''>formulas</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3181076672104404);'>inference</span> <span style=''>rules</span> <span style=''>are</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propositional</span> <span style=''>system</span> <span style=''>KE</span> <span style=''>a</span> <span style=''>tableau</span> <span style=''>like</span> <span style=''>analytic</span> <span style=''>proof</span> <span style=''>system</span> <span style=''>devised</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>both</span> <span style=''>as</span> <span style=''>a</span> <span style=''>refutation</span> <span style=''>and</span> <span style=''>a</span> <span style=''>direct</span> <span style=''>method</span> <span style=''>of</span> <span style=''>proof</span> <span style=''>enlarged</span> <span style=''>with</span> <span style=''>suitable</span> <span style='background-color:rgba(0, 255, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernels</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ensembles</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perspectives</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style=''>Learning</span> <br/><br/><span style=''>Since</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>emergence</span> <span style=''>in</span> <span style=''>the</span> <span style=''>1990s</span> <span style=''>the</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machine</span> <span style=''>and</span> <span style=''>the</span> <span style=''>AdaBoost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>have</span> <span style=''>spawned</span> <span style=''>a</span> <span style=''>wave</span> <span style=''>of</span> <span style=''>research</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Much</span> <span style=''>of</span> <span style=''>this</span> <span style=''>new</span> <span style=''>research</span> <span style=''>falls</span> <span style=''>into</span> <span style=''>one</span> <span style=''>of</span> <span style=''>two</span> <span style=''>broad</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categories</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>ensemble</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>this</span> <span style=''>expository</span> <span style=''>article</span> <span style=''>I</span> <span style=''>discuss</span> <span style=''>the</span> <span style=''>main</span> <span style=''>ideas</span> <span style=''>behind</span> <span style=''>these</span> <span style=''>two</span> <span style=''>types</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>namely</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>ones</span> <span style=''>by</span> <span style=''>using</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>how</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>with</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>or</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>models</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>a</span> <span style=''>single</span> <span style=''>model</span> <span style=''>I</span> <span style=''>also</span> <span style=''>share</span> <span style=''>my</span> <span style=''>personal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspectives</span> <span style=''>on</span> <span style=''>how</span> <span style=''>these</span> <span style=''>ideas</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influenced</span> <span style=''>and</span> <span style=''>shaped</span> <span style=''>my</span> <span style=''>own</span> <span style=''>research</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>I</span> <span style=''>present</span> <span style=''>two</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Causality</span> <span style=''>Networks</span> <br/><br/><span style=''>While</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>measures</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>discern</span> <span style='background-color:rgba(255, 0, 0, 0.3262260127931771);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>observed</span> <span style='background-color:rgba(255, 0, 0, 0.3559322033898305);'>variables</span> <span style=''>in</span> <span style=''>almost</span> <span style=''>all</span> <span style=''>branches</span> <span style=''>of</span> <span style=''>data</span> <span style=''>driven</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style=''>inquiry</span> <span style=''>what</span> <span style=''>we</span> <span style=''>are</span> <span style=''>really</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interested</span> <span style=''>in</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3666666666666666);'>dependence</span> <span style='background-color:rgba(0, 255, 0, 0.34146341463414637);'>Designing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>causality</span> <span style=''>test</span> <span style=''>that</span> <span style=''>may</span> <span style=''>be</span> <span style=''>carried</span> <span style=''>out</span> <span style=''>in</span> <span style=''>the</span> <span style=''>absence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315791);'>restrictive</span> <span style=''>pre</span> <span style=''>suppositions</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>at</span> <span style=''>hand</span> <span style=''>is</span> <span style=''>non</span> <span style=''>trivial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nevertheless</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style=''>infer</span> <span style='background-color:rgba(255, 0, 0, 0.3262260127931771);'>statistical</span> <span style=''>prima</span> <span style=''>facie</span> <span style=''>evidence</span> <span style=''>of</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3666666666666666);'>dependence</span> <span style=''>may</span> <span style=''>yield</span> <span style=''>a</span> <span style=''>far</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.5766423357664233);'>discriminative</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculation</span> <span style=''>of</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlations</span> <span style=''>In</span> <span style=''>the</span> <span style=''>present</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Identifying</span> <span style=''>Outliers</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Influence</span> <span style=''>Function</span> <span style=''>of</span> <span style=''>Multiple</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Canonical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <span style=''>Analysis</span> <br/><br/><span style=''>Imaging</span> <span style=''>genetic</span> <span style=''>research</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essentially</span> <span style=''>focused</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovering</span> <span style=''>unique</span> <span style=''>and</span> <span style=''>co</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>effects</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>ignoring</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>outliers</span> <span style=''>or</span> <span style=''>atypical</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>genetic</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>non</span> <span style=''>genetics</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>outliers</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>issue</span> <span style=''>for</span> <span style=''>imaging</span> <span style=''>genetics</span> <span style=''>and</span> <span style=''>multiple</span> <span style=''>sources</span> <span style=''>data</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>we</span> <span style=''>need</span> <span style=''>to</span> <span style=''>examine</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transcription</span> <span style=''>errors</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identified</span> <span style=''>outliers</span> <span style=''>First</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>function</span> <span style=''>(IF)</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>mean</span> <span style=''>element</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>operator</span> <span style=''>kernel</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>operator</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>analysis</span> <span style=''>(kernel</span> <span style=''>CCA)</span> <span style=''>and</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>CCA</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>IF</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>CCA</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13032670454545456)
# 	processing (0.10440340909090909)
# 	architecture (0.0859375)
# 	experimental (0.14417613636363635)
# 	segmentation (0.07990056818181818)
# 	information (0.25)
# 	detection (0.1260653409090909)
# 	different (0.27734375)
# 	convolutional (0.13636363636363635)
# 	recognition (0.1338778409090909)
#
# Some Statistics words are:
# 	stochastic (0.1381048387096774)
# 	algorithms (0.29586693548387094)
# 	theoretical (0.1532258064516129)
# 	variables (0.14112903225806453)
# 	estimation (0.17893145161290322)
# 	statistical (0.15675403225806453)
# 	distribution (0.17540322580645162)
# 	dimensional (0.18951612903225806)
# 	inference (0.20362903225806453)
# 	regression (0.18699596774193547)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c4a27da5-2d78-4141-9736-272087ebd448" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4a27da5-2d78-4141-9736-272087ebd448")) {                    Plotly.newPlot(                        "c4a27da5-2d78-4141-9736-272087ebd448",                        [{"x":["cluttered","relations","techniques","detecting","illumination","correctly","navigation","published","segmented","validated","environmental","detection","different","sequences","additionally","environments","classifiers","thoroughly","contribution","segmentation","algorithm","demonstrate","background","appropriate","conditional","estimates","practical","neighbourhood","indirectly","enforcing","maintained","continuity","sequential","representative","potentials","experiments","intervals","technique","structures","estimated","frequency","foreground","labelling","surveillance","filtering","computational","intensity","unavailable","considerably","complexity","estimation","framework","candidate","combination","conditions","circumstances","requirements","qualitatively","numerical","dimensional","algorithms","heuristic","clustering","adaptively","synthetic","improving","orthogonal","connectivity","efficiency","advantages","subspaces","separation","optimization","decomposition","particular","programming","outperforms","including","subgradient","performance","combinatorial","applicable","parameters","posteriors","comparison","application","distributions","inference","introduced","benchmarks","dimensions","independently","applications","increasing","corresponding","truncated","investigate","approaches","furthermore","saturates","independent","posterior","denoising","variational","independence","distribution","contributes","benchmark","properties","uncertainty","information","surprisingly","asymptotically","theoretic","shortcoming","simplicity","improvement","measurement","introduce","magnitude","measurements","modification","nevertheless","identification","collection","initiating","considered","incrementally","incorporated","probabilistic","simultaneously","avoidance","determined","extraction","resulting","configuration","likelihood","involving","membership","regularly","acquisition","motivated","exploration","construction","geostatistical","inclusion","principled","effective","functions","efficient","misleading","simulated","combining","considerations","portfolio","selection","definition","presented","regularized","objective","quantitative","preliminary","extensive","evaluation","consequence","classifier","evaluating","criterion","neuroimaging","optimizing","informative","interpretability","theoretical","automatic","circumvent","generation","narrative","difficult","important","interdependence","predicting","narratives","approximate","understanding","acquiring","knowledge","annotations","challenge","difficulties","collected","approximation","constrained","unconstrained","optimizers","approximated","questions","affirmative","challenging","polynomially","constrain","landscape","empirical","underlying","characterization","statistics","optimizations","prominently","introducing","factorization","gridworld","declarative","experimentally","continuous","improvements","selecting","correlated","integrating","representation","observable","separating","factoring","significant","observations","partially","dynamically","locations","reestimation","recognition","broadcast","rescoring","structure","structured","expectation","maximization","parameterization","perplexity","hierarchical","procedure","belonging","exploiting","presenting","significance","syntactic","vocabulary","rigorously","sparsification","probability","streaming","incremental","inequalities","subsequent","dependencies","martingale ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	geostatistical
# 	affirmative
# 	prominently
# 	martingale
# 	deconvnet
# 	bernsteins
# 	downweighting
# 	challenged
# 	integrator
# 	quadrature
# 	statistician
# 	periodicity
# 	extrapolation
# 	nonparametrically
# 	nonsmooth
# 	thresholded
# 	manufacturability
# 	duplicate
# 	scientist
# 	reassignment
# Some words which never appear in Statistics papers:
# 	cluttered
# 	initiating
# 	avoidance
# 	regularly
# 	reestimation
# 	quantifiers
# 	entanglement
# 	standardly
# 	multiword
# 	necessities
# 	discarded
# 	unimportant
# 	contestants
# 	adjectives
# 	realizing
# 	perceives
# 	multiplexing
# 	conclusive
# 	enthusiasm
# 	deblurring

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0556743873372856e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
